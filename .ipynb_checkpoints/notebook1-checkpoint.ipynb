# %%
from langchain_core.documents import Document         #importing documentt data structure

# %%
doc = Document(
    page_content= "password: fbcbhfe23232dd3f3 and ip:121.262.552.21",
    metadata={
        "source":"austin32327",
         "eid":"e6328392326366"
    }
)

# %%
doc
print(doc.metadata)
print(doc.page_content)
# Out:
# {'source': 'austin32327', 'eid': 'e6328392326366'}
# password: fbcbhfe23232dd3f3 and ip:121.262.552.21

# %%
from langchain_community.document_loaders import TextLoader  #text reader

# %%
loader = TextLoader("data1.txt",encoding="utf-8")
doc=loader.load()

# %%
for i, doc in enumerate(doc):
    print(f"Document {i} metadata:")
    for key, value in doc.metadata.items():
        print(f"  {key}: {value}")
    print("-" * 40)  # separator
# Out:
# Document 0 metadata:
#   source: data1.txt
# ----------------------------------------

# %%
from langchain_community.document_loaders import PyPDFLoader #pdf loader

# %%
loader=PyPDFLoader("data2.pdf")
doc=loader.load()
# Out:
#   0%|▌                                                                                                               | 1/213 [38:14<135:05:50, 2294.11s/it]

# %%
print(doc[6].page_content)
print("************************************************************************************************************************************************************")
print(doc[0].metadata)
# Out:
# Python Vocab
# • Keyword – Words with meaning/purpose in
# Python. E.g. “and”, “print”, and “if”.
# • Function – A chunk of code that performs an
# action. Functions have names and are reusable.
# Kinds: built-in ones, and “user-defined” ones.
# • Expression – Statements that produce values.
# Examples include 3 + 5, "Hello world!“.
# • Error – When your program has a problem, the
# command area will provide an error message.
# ************************************************************************************************************************************************************
# {'producer': 'Microsoft® Office PowerPoint® 2007', 'creator': 'Microsoft® Office PowerPoint® 2007', 'creationdate': 'D:20110801202339', 'title': 'Slide 1', 'author': 'Dyuchan', 'moddate': 'D:20110801202339', 'source': 'data2.pdf', 'total_pages': 91, 'page': 0, 'page_label': '1'}

# %%
for i, doc in enumerate(documents):
    print(f"\n--- Metadata for Page {i+1} ---")    # for all metadata
    print(doc.page_content)

# %%
from langchain_community.document_loaders import DirectoryLoader   #directory loader
import tqdm

# %%
# Load all TXT files
txt_loader = DirectoryLoader(
    "../RAG",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=True
)
txt_documents = txt_loader.load()

# Load all PDF files
pdf_loader = DirectoryLoader(
    "../RAG",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=True
)
pdf_documents = pdf_loader.load()

# Combine all docums
documents = txt_documents + pdf_documents

print(f"Loaded {len(documents)} documents.")
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.64it/s]
# Loaded 303 documents.

# %%
from langchain_community.document_loaders import WebBaseLoader # for loadiong web page

# %%
loader = WebBaseLoader("https://www.python.org/")
docs = loader.load()

docs[0].page_content[:1500]  # show first 500 characters
# Out:
# "\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWelcome to Python.org\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNotice: While JavaScript is not essential for this website, your interaction with the content will be limited. Please turn JavaScript on for the full experience. \n\n\n\n\n\n\nSkip to content\n\n\n▼ Close\n                \n\n\nPython\n\n\nPSF\n\n\nDocs\n\n\nPyPI\n\n\nJobs\n\n\nCommunity\n\n\n\n▲ The Python Network\n                \n\n\n\n\n\n\n\n\n\nDonate\n\n≡ Menu\n\n\nSearch This Site\n\n\n                                    GO\n                                \n\n\n\n\n\nA A\n\nSmaller\nLarger\nReset\n\n\n\n\n\n\nSocialize\n\nLinkedIn\nMastodon\nChat on IRC\nTwitter\n\n\n\n\n\n\n\n\n\n\nAbout\n\nApplications\nQuotes\nGetting Started\nHelp\nPython Brochure\n\n\n\nDownloads\n\nAll releases\nSource code\nWindows\nmacOS\nAndroid\nOther Platforms\nLicense\nAlternative Implementations\n\n\n\nDocumentation\n\nDocs\nAudio/Visual Talks\nBeginner's 
# ...

# %%
docs[0].metadata
# Out:
# {'source': 'https://www.python.org/',
#  'title': 'Welcome to Python.org',
#  'description': 'The official home of the Python Programming Language',
#  'language': 'en'}

# %%
for i, doc in enumerate(docs):
    print("\n----- Document", i+1, "-----")
    print("METADATA:", doc.metadata)
    print("CONTENT:", doc.page_content[:300], "...")
